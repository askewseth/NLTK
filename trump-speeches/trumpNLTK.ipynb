# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
with open('speeches.txt', 'r') as f:
    raw_text = [line.decode('utf-8').strip() for line in f.readlines()]

# %%
from ftfy import fix_text

# %%
raw_text = map(fix_text, raw_text)

# %%
words_nested = [word_tokenize(x) for x in raw_text]

# %%
words = [word.lower() for li in words_nested for word in li]

# %%
stringd = []
fails = []
for word in words:
    try:
        stringd.append(str(word))
    except:
        fails.append(word)

# %%
print len(stringd), len(fails)
# Out:
# 228625 2469

# %%
from collections import Counter

# %%
count = Counter()
for word in stringd:
    count[word] += 1

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
items = sorted(count.items(), key=lambda x: x[1], reverse=True)

# %%
from nltk.corpus import stopwords

# %%
items = [item for item in items if item not in stopwords.words('english')]

# %%
l, b = zip(*items)

# %%
indexes = np.arange(len(labels))
width = 1

# %%
plt.bar(indexes, values, width)
plt.xticks(indexes + width * 0.5, labels, rotation='vertical')
plt.show()

# %%
count['muslim'], count['christian'], count['mexican'], count['american'], count['clinton']
# Out:
# (12, 13, 16, 54, 94)

# %%
count['hilary'], count['bernie'], count['trump'], count['cruz'], count['carson']
# Out:
# (0, 12, 315, 60, 19)

# %%
count['sanders']
# Out:
# 9

# %%
count['wall'], count['great'], count['america']
# Out:
# (211, 726, 181)

# %%
count
# Out:
# Counter({'deferment': 1,
#          'dynamic': 2,
#          'foul': 2,
#          'Heights': 1,
#          'four': 65,
#          'protest': 3,
#          'Does': 19,
#          'Olympics': 1,
#          "candidates'": 1,
#          'preface': 1,
#          'captain': 1,
#          'Until': 4,
#          'aggression': 2,
#          'Schuster': 5,
#          'looking': 46,
#          'segments': 2,
#          'pensions': 1,
#          'quadruple': 1,
#          'Ronald': 1,
#          'protections': 2,
#          'Western': 6,
#          'sorry': 7,
#          'onstage': 1,
#          'Euro': 2,
#          'Hatzalah': 1,
#          'evangelical': 8,
#          'Frankly': 5,
#          'test-fired': 1,
#          'void': 1,
#          'regional': 1,
#          'misunderstanding': 1,
#          'smack': 1,
#          'reforms': 1,
#          'Old': 7,
#          'bringing': 33,
#          'vast': 6,
#          'Abbas': 1,
#          'dominate': 1,
#          'Low-energy': 2,
# ...

# %%
from nltk.corpus import stopwords

# %%
newitems = filter(lambda x: x[0].lower() not in stopwords.words('english'), items)

# %%
len(items), len(newitems)
# Out:
# (6519, 6304)

# %%
histitems = newitems[20:50]

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (15,15)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
labels, values = zip(*items)
indexes = np.arange(len(labels))
width = 1
plt.bar(indexes, values, width)
plt.xticks(indexes + width *0.5, labels, rotation='vertical')
plt.show()

# %%
labels, values = zip(*items[:100])
indexes = np.arange(len(labels))
width = 1
plt.bar(indexes, values, width)
plt.xticks(indexes + width *0.5, labels, rotation='vertical')
plt.show()

# %%
plt.bar(indexes, values, width)
plt.xticks(indexes + width *0.5, labels, rotation='vertical')
plt.show()

# %%
count['the']
# Out:
# 6029

# %%
count['christian']
# Out:
# 0

# %%
items[:20]
# Out:
# [('.', 17203),
#  (',', 9639),
#  ('i', 7307),
#  ('the', 6521),
#  ('to', 5997),
#  ('and', 5939),
#  ('we', 4442),
#  ('it', 4192),
#  ('you', 4101),
#  ('a', 4056),
#  ('they', 3747),
#  ("'s", 3474),
#  ('of', 3189),
#  ('that', 3158),
#  ('have', 2578),
#  ("'re", 2544),
#  ("n't", 2447),
#  ('do', 2335),
#  ('going', 2271),
#  ('in', 2227),
#  ('so', 1804),
#  ('is', 1749),
#  ('?', 1691),
#  ('but', 1617),
#  ('know', 1608),
#  ('people', 1501),
#  ('he', 1486),
#  ('be', 1295),
#  ('are', 1273),
#  ('this', 1156),
#  ('not', 1114),
#  ('for', 1102),
#  ('was', 1070),
#  ('``', 1068),
#  ('what', 1066),
#  ('with', 1024),
#  ("''", 1021),
#  ('our', 1016),
#  ("'m", 1008),
#  ('said', 935),
#  ('all', 924),
#  ('want', 911),
#  ('because', 897),
#  ('me', 866),
#  ("'ve", 795),
#  ('on', 794),
#  ('like', 762),
#  ('about', 760),
#  ('very', 756),
#  ('think', 752),
#  ('great', 726),
#  ('get', 717),
#  ('if', 691),
#  ('them', 678),
#  ('one', 676),
#  ('just', 628),
# ...
